# %%
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset)
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1333           0
# 1334           0
# 1335           0
# 1336           0
# 1337           1
#
# [1338 rows x 8 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1333           0
# 1334           0
# 1335           0
# 1336           0
# 1337           1
#
# [1338 rows x 8 columns]

# %%
independent=dataset[["age","bmi","children","sex_male","smoker_yes"]]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {'kernel': ['rbf','linear'],
              'C': [10, 100, 1000],
              'gamma': ['scale']}

grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000], 'gamma': ['scale'],
#                          'kernel': ['rbf', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_Score value for the best parameter{}:".format(grid.best_params_))
# Out:
# The R_Score value for the best parameter{'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.141074      0.005608         0.055687        0.006463      10
# 1       0.149132      0.012753         0.015196        0.004421      10
# 2       0.150528      0.004890         0.059619        0.011134     100
# 3       0.269136      0.005822         0.021818        0.005607     100
# 4       0.167430      0.005849         0.068570        0.006783    1000
# 5       0.815041      0.071737         0.017844        0.001584    1000
#
#   param_gamma param_kernel                                             params  \
# 0       scale          rbf       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 1       scale       linear    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 2       scale          rbf      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 3       scale       linear   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
# 4       scale          rbf     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 5       scale       linear  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0          -0.110409          -0.097459          -0.074488          -0.099597
# 1          -0.018943           0.029886           0.022167           0.003112
# 2          -0.160182          -0.107253          -0.123430          -0.137753
# 3           0.559313           0.521798           0.547691           0.538805
# 4          -0.155430          -0.098267          -0.123724          -0.137137
# 5           0.736398           0.675162           0.680002           0.699377
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0          -0.124428        -0.101276        0.016459                4
# 1          -0.066653        -0.006086        0.034672                3
# 2          -0.209551        -0.147634        0.035511                6
# 3           0.508518         0.535225        0.018122                2
# 4          -0.206405        -0.144193        0.036262                5
# 5           0.677952         0.693778        0.022955                1

# %%
age=int(input("Enter the age:"))
bmi=float(input("Enter the bmi:"))
children=int(input("Children:"))
sex_male=int(input("Sex male 0 or 1:"))
smoker=int(input("smoker yes or no 0 or 1:"))
# Out:
# Enter the age:27
# Enter the bmi:29
# Children:2
# Sex male 0 or 1:0
# smoker yes or no 0 or 1:0

# %%
Future_Prediction = grid.predict([[age, bmi, children, sex_male, smoker]])
print("Future prediction={}".format(Future_Prediction[0]))
# Out:
# Future prediction=4362.172584880868
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
